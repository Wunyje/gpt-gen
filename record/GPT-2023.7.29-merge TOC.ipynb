# %%
import openai
import os
import cryptocode
import my_prompt

os.environ["http_proxy"]="127.0.0.1:10810"
os.environ["https_proxy"]="127.0.0.1:10810"
encrypt_key = '+jPnEOUhc49yoEKpqTAPiSenr4dGz37Add436GjHSXyM2wvqpDvkIfaH51vDeDPElfee*SV8GL/gwJJdXjtGe1Y8sdA==*vpovYFJYnDuD6ALUJlazFg==*m+DOSfnpsLovZfrzYmwPyA=='
openai.api_key  = cryptocode.decrypt(encrypt_key, "wunyje-key")
def get_completion(prompt, model="gpt-3.5-turbo", temperature=0):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages
    )
    return response.choices[0].message["content"]

def Copy_To_Clipboard( string ):
    """ 将需要的字符串或文字复制到剪切板. """
    from tkinter import Tk
    r = Tk()
    r.withdraw()
    r.clipboard_clear()
    r.clipboard_append(string)
    r.update()

# %%
text_1 = f"""
目录

第一牵”数制和和袜制 .arerrraawsaeaermassaaaaasiaaaanapaasiaasnaeasaaanauaaassapnpenwaarasranseen 玫
1.3 不同数制间的转换 6
2.3 逻辑代数的基本公式和常用公式 pp 4
2.5.2 逐辑函数的描述方法 pp 29
2.6.1 公式化简法 37
I 目录
*# 2.6.3 奎恩-才克拉斯基化简法1Q=M 法) 44
元7.1 约束项 .任意项和逻辑函数起中的无关项 pp
2.7.2 无关项在化简远辑丽数中的应用 9
本章小缚 4
3.2.1 半导体三极管的开关特性64
3.3.1 MOS管的开美特性 68
3.3.2 CMOS 反相器的电路结构和工作原理 73
3.3.3 CMOS 反相器的静态输入特性和输出特性 7
3.3.4 CM0OS 反相器的动态特性 80
3.3.5 其他类型的CMOS 门电路 和 85
3.3.6 CMOS 集成电路的正确使用 9
3.3.7 CMOS 数字集成电路的各种系列,的 96
3.4 TELE门电路 和99
3.4.2 TITL 反相器的电路结构和工作原理 or 105
3.4.3 TIL反相器的静态输入特性和输出特性 1107
3.4.4 TTL反相器的动态特性 pp 1
3.4.5 其他类型的TTL 门电路1115
3.4.6 _TTL 数字集成电路的各种系列 pp 122
闪3.5 ECL 集成电路 26
3.5.1 ECL电路的基本结构和工作原理 126
3.5.2 ECL 集成电路的各种系列1128
3.6 BECMOS 电路129
3.6.1 Bi-CMOS 电路的基本结构和工作原理 pp 129
3.6.2 Bi-CMOS 集成电路的各种系列 1130
3.7 ”不同类型数字集成电路间的接口132
3.7.1 CMOS 电路和TTL 电路的接口 站 132
目录 。 亚

3.7.2 不同多辑电平电路间的接辐和 134
4.3 组合逐辑电路的基本设计方法pp 49
4.4 若干常用的组合逻辑电路模块PR 52
4.5 层次化和模块化的设计方法179
4.6 可编程逻辑器件站1184
4.7 硬件描述语言1186
4.8  用可编程通用模块设计组合多辑电路 90
4.9  组合罗辑电路中的竞争-冒险 or 94
4.9.2 检查竞争-冒险现象的方法 pp 196
4.9.3 消除竞争-冒险现象的方法 pe 97
本章小结 99
5.3.2 边沿触发的触发器 215
5.5.1 静态随机存储器(SRAM) pp 231

* 5.5.2 动态随机存储器(DRAM) pp 2234
IV 目录
5.5.3  只读存储器(ROM ) oossosooovsooooooevrosooooooooooooooooooooooeoovooooooooo ooeooooooovoov oo 236
5.5.5  用存储几实现组合迎辑霄数各ooe ee 244
6.2.1 同步时序逻辑电路的分析方法 2263
6.2.2 时序辑电路的状态转换表 ,状态转换图,状态机流程图和时序图 pp 264
*# 6.2.3 异步时序逻辑电路的分析方法270
6.3 若干常用的时序远辑电路271
6.4.1 同步时序逻和辑电路的设计方法 310
6.4.2 时序逻辑电路的自启动设计和320
*# 6.4.3 异步时序逻辑电路的设计方法 324
6不而 复困时序速辑电路的设计《arceenisressnseenneraasroooeseaarraseaosmraresooassansoooereeeeoeeois 328
6.5 用可编程逻辑器件实现同步时序逻和辑电路 330
6.5.1 可以实现时序罗辑电路的可编程逻辑器件 pp 330
6.5.2 用硬件描述语言 Verilog HDL 描述时序逻辑电路 331
6.6 时序逻辑电路中的竞争-冒险现象36
7.2.1 施密特触发电路的结构和工作原理 pp 350
7.2.2 用门电路组成的施密特触发电路 pp 353
7.3,.1 用门电路组成的单稳态电路站3357
目录  V

7.4.2，非对称式多谐振荡电路367
7.4.4 用施密特触发电路构成的多谐振功电路3372
7.4.5 石英晶体多谐振菏电路374
7.5.1 555 定时器的电路结构和功能 375
7.5.2 用555 定时器接成的施密特甬发电路3377
7.5.4 用555 定时器接成的多谐振菏电路 379
本章小结 2
8.2 DZA 转换器的电路结构和工作原理 生  389
8.2.1 权电阻网络 D/A 转换器3389
8.2.2 倒T形电阻网络 DA 转换器 pp 391
8.2.3 权电流型 D7A 转换器 pp 393
8.2.6 具有双极性输出的 DA/A 转换器398
8.3.1 D/A 转换器的转换精度pp 400
8.3.2 D/XA 转换器的转换速度404
8.6 AZD 转换器的电路结构和工作原理生 408
* 8.6.2 藻水线型 AXD 转换叶 0
8.6.6 一玉 变换型 AXD 转换器 pp 421
8.7 AZD 转换器的转换精度与转换速度pp 426
8.7.1 AZD 转换器的转换精度pp 426
8.7.2 AZD 转换器的转换速度pp 27
L 目录
soneeypeyeyadsanaREpeaisarapveBLEuEEERsResr ovonRvnE6EUEEERScdE ionroaudr3 鲍昌
本 eaanedeaaaankssweaaueapsseukaealgIaRem meraapvaiarvaSREEREcuiesseernanalsdEs Eueeooronnesid 芭
附录一“可编程逻辑器件(PLD ) 分类435
附录二 《电气简图用图形符号一一二进制逻辑单元》
(GBZT 4728. 12一2005 ) 简介.53
附录三“基本远辑单元图形符号对照表 62
部红河题过睫=weoryrrraenaasapassearahaovsqpayaaeoaanurngmayanpideaaauanaanEraaniiaenacoreaccnici 介0
套海变韦ssesaeseaaaerspessrsanmmnas sranoraaaarsanraysianramaaaaataaszpiugaaaastsaanasaameawesainne 几
洛祝攀绰 =aaeaooraesmapwasaoasriaenersaakwasapwoeawasaaapaesaaasaawaapapespaianasaanassmoarmuanmmacnianaaa 全
"""

# %%
text_2 = f"""
第一章“”数制和码制
几种常用的数制
不同数制间的转换
二进制算术运算
二进制算术运算的特点
4.2 反码,补码和补码运算
几种常用的编码
本章小结 …
第二章 ”逻辑代数基础…
逻辑代数中的三种基本运算
逻辑代数的基本公式和常用公
基本公式
这网络 式
若干常用公式
逻辑代数的基本定理
代入定理
演定理
2.4.3 对偶定理
逻辑函数及其描述方法
逻辑函数
膛辑函数的描述方法
5.3 逻辑函数的两种标准形式
逻辑函数的化简方法
公式化简法
6.2 卡诺图化简法
奎恩-麦克拉斯基化简法(Q-M法)
具有无关项的罗辑函数及其化简
约东项 .任意项和逻辑函数式中的无关项
无关项在化简逻辑函数中的应用
多输出多得函数的化简
有多和辑函数形式的变换
本章小结 …
第三章
门电路
3.2 半导体二极管门电路
拉导体二极管的开关特性
二极管与门
极管或门
CMOS 门电路
MOS 管的开关特性
CMOS 反相器的电路结构和工作原理
CMOS 反相器的静态输入特性和输出特性
CMOS 反相器的动态特性
其他类型的 CMOS 门电路
CMOS 集成电路的正确使用
CMOS 数字集成电路的各种系列…
TTL门电路 ，
双极型三极管的开关特性
TTL 反相器的电路结构和工作原
TITL 反相器的青态输入特性和输出特性
TTL 反相器的动态特性
其他类型的 TTL 门电路
TTL 数字集成电路的各种系列
ECL 集成电路
ECL 电路的基本结构和工作原理
ECL 集成电路的各种系列
BiLCMOS 电路
Bi-CMOS 电路的基本结构和工作原理
6.2 Bi-CMOS 集成电路的各种系列
不同类型数字集成电路间的接口
CMOS 电路和TTL 电路的接口
不同逻辑电平电路间的接口
本章小结
第四章
组合逻辑电路
组合逻得电路的分析方法
组合和辑电路的基本设
计方法
若干常用的组合罗得电路模块
编码器
译码器
数据选择器
加法器
数值比较器
次化和模块化的设计方法
可编程多得器件
硬件描
用可编程通用模块设计组合逻辑电路
膛旬电路中的竞争-冒险
险现象及其成因
9%9.2 检查竞争-冒险现象的方法
消除竞争-冒险现象的方法
本章小结
第五章
SR 锁存器
触发器
电平触发的触发器
边沿触发的触发器
脉冲触发的触发器
3.4 和触发器按逻辑功能的分类
.3.5 和触发器的动态特性“
寄存器 ，
存储器
萌态随机存储器(SRAM)
动态随机存储器(DRAM)
只读存储器(ROM )
5.5.4 存储器容量的扩
用存储器实现组合罗辑函数
本章小结
六章 ww
时序远辑电路的分析方法
同步时序逻辑电路的分析方法
时序罗辑电路的状态转换表 ,状态转换图 ,状态机流程图和时序图
2.3 异步时序逻辑电路的分析方法…
若干常用的时序示辑电路
移位寄存器
计数器
顺序脉冲发生器
3.4 序列信
发生器
时序过辑电路的设计方法
同步时序逻辑电路的设计方法
时序罗辑电路的自启动设计
异步时序罗辑电路的设计方法
杂时序逻辑电路的设计
用可编程逻辑器件实现同步时序巡辑电路
可以实现时序逻辑电路的可编程逻辑器件
6.5.2 用硬件描述语言 Verilog HDL 描述时序逻辑电路
6.6 时序逻得电路中的竞争-冒险现象 ，
本章小结
第七章 ”脉冲波形的产生和整形电路
7.2 施密特触发电路
施密特触发电路的结构和工作原理
2 用门电路组成的施密特触发电路
7.2.3 施密特触发电路的应用
7.3 单稳态电路
用门电路组成的单稳态电路…
7.3.2 集成单稳态电路
7.4 多谐振荡电路
对称式多谐振荡电路
4.2 非对称式多谐振功电路
4.3 环形振荡电路
4.4 用施密特触发电路构成的多谐振荡电路
4.5 石英晶体多谐振荡电路
555 定时器及其应用
555 定时器的电路结构和功能
用555 定时器接成的施密特触发电路
555 定时器接成的单稳态电路
555 定时器接成的多谐振荡电路
本章小
第八章“”数-模和模-数转换
D7A 转换器的电路结构和工作原理
权电阻网络 DZA 转换器
倒T形电阻网络 DZA 转换器
权电流型 DZA 转换器
开关树型 D7A 转换器
权电容网络 D/A 转换器
具有双极性输出的 DZA 转换器
D7A 转换器的转换精度与转换速度
D/A 转换器的转换精度
3.2 D7VA 转换器的转换速度
AZD 转换的基本原理
取样-保持电路
AZD 转换器的电路结构和工作原理
并联比较型 AZD 转换器
流水线型 AD 转换器
逐次通近型 AZD 转换器
积分型 AD 转换器
工-A型 A/D 转换器
f有变换型 AZD 转换器
AZD 转换器的转换精度与转换速度
AZD 转换器的转换精度
AZD 转换器的转换速度
本章小结
附录一
可编程逻辑器件(PLD ) 分类
附录二
《电气简图用图形符号一一二进制逻辑单元》
(GBZT 4728. 12一2005 ) 简介…
附录三
基本逻辑单元图形符号对照表
部分习题答案
参考文献
名词索引
"""

# %%
prompt_1 = f"""
Reorgnize and modify this *text_1* of *table of content*, \
keep the origin section number and page number, *leave the \
things blank if you don't know*, output `outline_1` in \
hirachical pdf outline's format in origin language. 
*format requirement*:
```
第一章 标题 $page_num$
    1.1 次标题    $page_num$
        1.1.1 次次标题  $page_num$
```
*text_1*:
```
{text_1}
```
"""

Copy_To_Clipboard(prompt_1)

# %%
text_2 = f"""
第一章“”数制和码制
几种常用的数制
不同数制间的转换
二进制算术运算
二进制算术运算的特点
4.2 反码,补码和补码运算
几种常用的编码
本章小结 …
第二章 ”逻辑代数基础…
逻辑代数中的三种基本运算
逻辑代数的基本公式和常用公
基本公式
这网络 式
若干常用公式
逻辑代数的基本定理
代入定理
演定理
2.4.3 对偶定理
逻辑函数及其描述方法
逻辑函数
膛辑函数的描述方法
5.3 逻辑函数的两种标准形式
逻辑函数的化简方法
公式化简法
6.2 卡诺图化简法
奎恩-麦克拉斯基化简法(Q-M法)
具有无关项的罗辑函数及其化简
约东项 .任意项和逻辑函数式中的无关项
无关项在化简逻辑函数中的应用
多输出多得函数的化简
有多和辑函数形式的变换
本章小结 …
第三章
门电路
3.2 半导体二极管门电路
拉导体二极管的开关特性
二极管与门
极管或门
CMOS 门电路
MOS 管的开关特性
CMOS 反相器的电路结构和工作原理
CMOS 反相器的静态输入特性和输出特性
CMOS 反相器的动态特性
其他类型的 CMOS 门电路
CMOS 集成电路的正确使用
CMOS 数字集成电路的各种系列…
TTL门电路 ，
双极型三极管的开关特性
TTL 反相器的电路结构和工作原
TITL 反相器的青态输入特性和输出特性
TTL 反相器的动态特性
其他类型的 TTL 门电路
TTL 数字集成电路的各种系列
ECL 集成电路
ECL 电路的基本结构和工作原理
ECL 集成电路的各种系列
BiLCMOS 电路
Bi-CMOS 电路的基本结构和工作原理
6.2 Bi-CMOS 集成电路的各种系列
不同类型数字集成电路间的接口
CMOS 电路和TTL 电路的接口
不同逻辑电平电路间的接口
本章小结
第四章
组合逻辑电路
组合逻得电路的分析方法
组合和辑电路的基本设
计方法
若干常用的组合罗得电路模块
编码器
译码器
数据选择器
加法器
数值比较器
次化和模块化的设计方法
可编程多得器件
硬件描
用可编程通用模块设计组合逻辑电路
膛旬电路中的竞争-冒险
险现象及其成因
9%9.2 检查竞争-冒险现象的方法
消除竞争-冒险现象的方法
本章小结
第五章
SR 锁存器
触发器
电平触发的触发器
边沿触发的触发器
脉冲触发的触发器
3.4 和触发器按逻辑功能的分类
.3.5 和触发器的动态特性“
寄存器 ，
存储器
萌态随机存储器(SRAM)
动态随机存储器(DRAM)
只读存储器(ROM )
5.5.4 存储器容量的扩
用存储器实现组合罗辑函数
本章小结
六章 ww
时序远辑电路的分析方法
同步时序逻辑电路的分析方法
时序罗辑电路的状态转换表 ,状态转换图 ,状态机流程图和时序图
2.3 异步时序逻辑电路的分析方法…
若干常用的时序示辑电路
移位寄存器
计数器
顺序脉冲发生器
3.4 序列信
发生器
时序过辑电路的设计方法
同步时序逻辑电路的设计方法
时序罗辑电路的自启动设计
异步时序罗辑电路的设计方法
杂时序逻辑电路的设计
用可编程逻辑器件实现同步时序巡辑电路
可以实现时序逻辑电路的可编程逻辑器件
6.5.2 用硬件描述语言 Verilog HDL 描述时序逻辑电路
6.6 时序逻得电路中的竞争-冒险现象 ，
本章小结
第七章 ”脉冲波形的产生和整形电路
7.2 施密特触发电路
施密特触发电路的结构和工作原理
2 用门电路组成的施密特触发电路
7.2.3 施密特触发电路的应用
7.3 单稳态电路
用门电路组成的单稳态电路…
7.3.2 集成单稳态电路
7.4 多谐振荡电路
对称式多谐振荡电路
4.2 非对称式多谐振功电路
4.3 环形振荡电路
4.4 用施密特触发电路构成的多谐振荡电路
4.5 石英晶体多谐振荡电路
555 定时器及其应用
555 定时器的电路结构和功能
用555 定时器接成的施密特触发电路
555 定时器接成的单稳态电路
555 定时器接成的多谐振荡电路
本章小
第八章“”数-模和模-数转换
D7A 转换器的电路结构和工作原理
权电阻网络 DZA 转换器
倒T形电阻网络 DZA 转换器
权电流型 DZA 转换器
开关树型 D7A 转换器
权电容网络 D/A 转换器
具有双极性输出的 DZA 转换器
D7A 转换器的转换精度与转换速度
D/A 转换器的转换精度
3.2 D7VA 转换器的转换速度
AZD 转换的基本原理
取样-保持电路
AZD 转换器的电路结构和工作原理
并联比较型 AZD 转换器
流水线型 AD 转换器
逐次通近型 AZD 转换器
积分型 AD 转换器
工-A型 A/D 转换器
f有变换型 AZD 转换器
AZD 转换器的转换精度与转换速度
AZD 转换器的转换精度
AZD 转换器的转换速度
本章小结
附录一
可编程逻辑器件(PLD ) 分类
附录二
《电气简图用图形符号一一二进制逻辑单元》
(GBZT 4728. 12一2005 ) 简介…
附录三
基本逻辑单元图形符号对照表
部分习题答案
参考文献
名词索引
"""

# %%
prompt_2 = f"""
Reorgnize and modify this `text_2` of the same *table of content* \
with `text_1, merge into the `outline_1` to get `final_outline`, \
keep the origin section number and page number of `outline_1`, \
*leave the things blank if you don't know* output outline_1 in \
hirachical pdf outline's format in origin language: 
```{text_2}```"""

answer_2 = get_completion(prompt_1)

print(answer_2)

prompt = f"""
Merge `text_1` and `text_2` into `text_3`: Mainly basing on \
`text_1`, insert `text_2`'s titles which are not contained by \
`text_1`, noticing that `text_1`'s *section number* and *page \
number* are more reliable, `text_2`'s titles are more accurate, \
but doesn't contain many *section number* and *page number*.
"""
